# %% [markdown]
# # Conexão com Storage

# %% [markdown]
# ###### Função responsável por fazer a conexão com o storage

# %%
def mount_blob(account_name, account_key, container):
  blob_prefix = f"wasbs://{container}@{account_name}.blob.core.windows.net/"
  dbutils.fs.mount(
    source = blob_prefix,
    mount_point = f"/mnt/{container}",
    extra_configs = {
      f"fs.azure.account.key.{account_name}.blob.core.windows.net":account_key
    }
  )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ###### Executando função de conexão passando chaves de acesso direta (precisa refatorar função acima)

# %%
mount_blob("projetointegradogrupob", "zCn5CL5DMYQxGrbxqPQILAsmU4IUgYanPlAxZrW0vIyDXdmELb9D8CegCDDIry/xGOrPlp1ZyS0XUExg6s9fwA==", "landing")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ExecutionError</span>                            Traceback (most recent call last)
# ...
