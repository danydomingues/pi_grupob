# %% [markdown]
# # Download, Descompactação e Armazenamento

# %% [markdown]
# ###### Criando dicionário que contém uma lista com a URL de download e o nome do arquivo que será baixado.

# %%
import urllib

# Arquivos datatran2021.csv.zip, datatran2020.csv.zip e 'datatran2019.csv.zip' via url
url = {
  "datatran2021":["https://storage.googleapis.com/kaggle-data-sets/933150/2539105/compressed/por_ocorrencia/datatran2021.csv.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20210906%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210906T122622Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...", "datatran2021.csv.zip"],
  
  
  "datatran2020":["https://storage.googleapis.com/kaggle-data-sets/933150/2539105/compressed/por_ocorrencia/datatran2020.csv.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20210906%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210906T122727Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...", "datatran2020.csv.zip"],
  
  "datatran2019":["https://storage.googleapis.com/kaggle-data-sets/933150/2539105/compressed/por_ocorrencia/datatran2019.csv.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20210906%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210906T122821Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...", "datatran2019.csv.zip"]
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ###### Fazendo leitura das informações acima para efetuar o download dos arquivos e os armazenar no storage.

# %%
urllib.request.urlretrieve(url["datatran2021"][0], "/dbfs/mnt/landing/web_scraping/prf/raw/ocorrencias/{}".format(url["datatran2021"][1]))
urllib.request.urlretrieve(url["datatran2020"][0], "/dbfs/mnt/landing/web_scraping/prf/raw/ocorrencias/{}".format(url["datatran2020"][1]))
urllib.request.urlretrieve(url["datatran2019"][0], "/dbfs/mnt/landing/web_scraping/prf/raw/ocorrencias/{}".format(url["datatran2019"][1]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: (&#39;/dbfs/mnt/landing/web_scraping/prf/raw/ocorrencias/datatran2019.csv.zip&#39;,
#  &lt;http.client.HTTPMessage at 0x7f3f2007d610&gt;)</div>

# %% [markdown]
# ###### Extraindo arquivos .csv

# %%
from zipfile import ZipFile

datatran2021 = ZipFile("/dbfs/mnt/landing/web_scraping/prf/raw/ocorrencias/{}".format(url["datatran2021"][1]), "r")
datatran2021.extract("datatran2021.csv", "/dbfs/mnt/landing/web_scraping/prf/raw/ocorrencias/")

datatran2021 = ZipFile("/dbfs/mnt/landing/web_scraping/prf/raw/ocorrencias/{}".format(url["datatran2020"][1]), "r")
datatran2021.extract("datatran2020.csv", "/dbfs/mnt/landing/web_scraping/prf/raw/ocorrencias/")

datatran2019 = ZipFile("/dbfs/mnt/landing/web_scraping/prf/raw/ocorrencias/{}".format(url["datatran2019"][1]), "r")
datatran2019.extract("datatran2019.csv", "/dbfs/mnt/landing/web_scraping/prf/raw/ocorrencias/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: &#39;/dbfs/mnt/landing/web_scraping/prf/raw/ocorrencias/datatran2019.csv&#39;</div>

# %% [markdown]
# ###### Deletando os arquivos .zip do storage de forma recursiva

# %%
# %fs rm -r dbfs:/mnt/landing/web_scraping/prf/raw/ocorrencias/datatran2021.csv.zip
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res0: Boolean = true
# </div>

# %%
# %fs rm -r dbfs:/mnt/landing/web_scraping/prf/raw/ocorrencias/datatran2020.csv.zip
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = true
# </div>

# %%
# %fs rm -r dbfs:/mnt/landing/web_scraping/prf/raw/ocorrencias/datatran2019.csv.zip
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Boolean = true
# </div>
