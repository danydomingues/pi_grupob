# %% [markdown]
# # Download, Descompactação e Armazenamento

# %% [markdown]
# ###### Criando dicionário que contém uma lista com a URL de download e o nome do arquivo que será baixado.

# %%
import urllib

# Arquivos acidentes2021.csv.zip, acidentes2020.csv.zip e 'acidentes2019.csv.zip' via url
url = {
  "acidentes2021":["https://storage.googleapis.com/kaggle-data-sets/933150/2539105/compressed/por_pessoa/acidentes2021.csv.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20210906%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210906T123033Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...", "acidentes2021.csv.zip"],
  
  "acidentes2020":["https://storage.googleapis.com/kaggle-data-sets/933150/2539105/compressed/por_pessoa/acidentes2020.csv.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20210906%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210906T123118Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...", "acidentes2020.csv.zip"],
  
  "acidentes2019":["https://storage.googleapis.com/kaggle-data-sets/933150/2539105/compressed/por_pessoa/acidentes2019.csv.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20210906%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210906T123152Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...", "acidentes2019.csv.zip"]
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: (&#39;/dbfs/mnt/landing/web_scraping/prf/raw/pessoas/acidentes2019.csv.zip&#39;,
#  &lt;http.client.HTTPMessage at 0x7f5248e733a0&gt;)</div>

# %% [markdown]
# ###### Fazendo leitura das informações acima para efetuar o download dos arquivos e os armazenar no storage.

# %%
urllib.request.urlretrieve(url["acidentes2021"][0], "/dbfs/mnt/landing/web_scraping/prf/raw/pessoas/{}".format(url["acidentes2021"][1]))
urllib.request.urlretrieve(url["acidentes2020"][0], "/dbfs/mnt/landing/web_scraping/prf/raw/pessoas/{}".format(url["acidentes2020"][1]))
urllib.request.urlretrieve(url["acidentes2019"][0], "/dbfs/mnt/landing/web_scraping/prf/raw/pessoas/{}".format(url["acidentes2019"][1]))

# %% [markdown]
# ###### Extraindo arquivos .csv

# %%
from zipfile import ZipFile

acidentes2021 = ZipFile("/dbfs/mnt/landing/web_scraping/prf/raw/pessoas/{}".format(url["acidentes2021"][1]), "r")
acidentes2021.extract("acidentes2021.csv", "/dbfs/mnt/landing/web_scraping/prf/raw/pessoas/")

acidentes2020 = ZipFile("/dbfs/mnt/landing/web_scraping/prf/raw/pessoas/{}".format(url["acidentes2020"][1]), "r")
acidentes2020.extract("acidentes2020.csv", "/dbfs/mnt/landing/web_scraping/prf/raw/pessoas/")

acidentes2019 = ZipFile("/dbfs/mnt/landing/web_scraping/prf/raw/pessoas/{}".format(url["acidentes2019"][1]), "r")
acidentes2019.extract("acidentes2019.csv", "/dbfs/mnt/landing/web_scraping/prf/raw/pessoas/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: &#39;/dbfs/mnt/landing/web_scraping/prf/raw/pessoas/acidentes2019.csv&#39;</div>

# %% [markdown]
# ###### Deletando os arquivos .zip do storage de forma recursiva

# %%
# %fs rm -r dbfs:/mnt/landing/web_scraping/prf/raw/pessoas/acidentes2021.csv.zip
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res0: Boolean = true
# </div>

# %%
# %fs rm -r dbfs:/mnt/landing/web_scraping/prf/raw/pessoas/acidentes2020.csv.zip
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = true
# </div>

# %%
# %fs rm -r dbfs:/mnt/landing/web_scraping/prf/raw/pessoas/acidentes2019.csv.zip
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Boolean = true
# </div>
